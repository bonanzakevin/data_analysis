# %%
import pandas as pd
import os
os.chdir("/Users/kevin/Downloads")
buyer_sample_social = pd.read_csv('buyer_sample_social.csv')

# %%
print(buyer_sample_social)
# Out:
#      Unnamed: 0       Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      buyer_id             city         state    country       name
# 1          1054      San Antonio            CA         US      carol
# 2         33970           aurora            IL         US      susie
# 3        354843         Oil City            PA         US      kelly
# 4        791436   Valley Cottage            NY         US    loretta
# 5        826959        Villanova            PA         US       eric
# 6       1005618         Kingston            PA         US     dennis
# 7       1080479     Ormond Beach            FL         US        NaN
# 8       1093190         Lakeland            FL         US       john
# 9       1246653          buffalo            MN         US     austin
# 10      1446643          Yonkers            NY         US       eric
# 11      2118711           Dublin            OH         US     andrew
# 12      3746461        Pemberton            NJ         US    anthony
# ...

# %%
ids = buyer_sample_social.
